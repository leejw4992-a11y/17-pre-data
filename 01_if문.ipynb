# %%
# if문은 왜 필요할까?
## 돈이 있으면 택시를 타고가고 돈이 없으면 걸어가라.

money = True
if money ==True: #(조건문)
	print('택시를 타고가라')
else:
	print('걸어가라')
# Out:
# 택시를 타고가라

# %%
# if문의 구조

# if 조건문: #Ture or False 가 들어가는 자리, : (그러면이라는 뜻의 콜론)
# 	수행할 문장1
# 	수행할 문장2
# else:
# 	수행할 문장3
# 	수행할 문장4

# %%
# 들여쓰기 방법
money = True
if money:  #위에 조건이 있기때문에 뒤에 트루를 안적어줘도됨.
	print('택시를')
	
print('타고')
	print('가라')
# Out:
#   Cell In[4], line 7
#     print('가라')
#     ^
# IndentationError: unexpected indent

# %%
if money:  
	print('택시를')
	print('타고')
		print('가라')
# Out:
#   Cell In[5], line 4
#     print('가라')
#     ^
# IndentationError: unexpected indent

# %%
if money:  
	print('택시를')
	print('타고')
 print('가라')
# Out:
#   File <string>:4
#     print('가라')
#                ^
# IndentationError: unindent does not match any outer indentation level

# %%
# '만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 가고 그렇지 않으면 걸어가라'

money = 3000
if money >= 3000 :
	print("택시를 타고가라")
else:
	print("걸어가라")
# Out:
# 택시를 타고가라

# %%
#돈이 3000원 이상 있거나 카드가 있다면 택시를 타고가고 그렇지 않으면 걸어가라

money = 2000
card = True

if money >= 3000 or card ==True:
	print("택시를 타고가라")
else:
	print("걸어가라")
# Out:
# 택시를 타고가라

# %%
#다양한 조건을 판단하는 elif

#주머니에 돈이 있으면 택시를 타고 가고 
#주머니에 돈은 없지만 카드가 있으면 택시를 타고가고
#돈도 없고 카드도 없으면 걸어가라

pocket = ['paper', 'phone']
card = True

if 'money' in pocket:
	print("1. 택시를 타고가라")
if 'money' not in pocket and card ==True:
	print("2. 택시를 타고가라")
if 'money'not in pocket and card == False:
	print('걸어가라')
# Out:
# 2. 택시를 타고가라

# %%
#주머니에 돈이 있으면 택시를 타고 가고 
#주머니에 돈은 없지만 카드가 있으면 택시를 타고가고
#돈도 없고 카드도 없으면 걸어가라

pocket = ['paper', 'phone']
card = False

if 'money' in pocket:
	print("1. 택시를 타고가라")
elif card ==True:
	print("2. 택시를 타고가라")
else:
	print('걸어가라')
# Out:
# 걸어가라
